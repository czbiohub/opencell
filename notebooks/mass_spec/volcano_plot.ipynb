# %%
import sys
sys.path.append('/Users/kibeom.kim/Documents/GitHub/opencell/opencell/mass_spec/')
import pandas as pd
import plotly_volcano as pv

# %% [markdown]
# ### Import enrichment/pval calculated database

# %%
master = pd.read_pickle('/Users/kibeom.kim/Documents/GitHub/opencell/opencell/mass_spec/cache/P14_25_pvals_removal_v0.1.pkl')

# %% [markdown]
# ### Volcano plot!

# %%
# imp.reload(pv)
pv.volcano_plot(master,'ATL3',[3.5,2.55])
# Out:
# Number of Significant Hits: 8

# %% [markdown]
# ### List of Baits

# %%
set(master.columns.get_level_values('baits').tolist())
# Out:
# {'AAMP',
#  'AATF',
#  'ABCE1',
#  'ABR',
#  'ACAP2',
#  'ACAP3',
#  'ACLY',
#  'ACTR2',
#  'AGAP1',
#  'AGAP3',
#  'AKAP12',
#  'AKAP13',
#  'AKR1A1',
#  'AKT1',
#  'ALDH16A1',
#  'ALDH7A1',
#  'ALDH9A1',
#  'ALG2',
#  'ANAPC11',
#  'ANAPC16',
#  'ANAPC2',
#  'ANAPC4',
#  'ANLN',
#  'ANXA11',
#  'APC',
#  'APPL1',
#  'APPL2',
#  'ARAP1',
#  'ARF1',
#  'ARF3',
#  'ARF4',
#  'ARF5',
#  'ARF6',
#  'ARFGAP2',
#  'ARFGAP3',
#  'ARFGEF2',
#  'ARFIP1',
#  'ARHGAP1',
#  'ARHGAP11A-B',
#  'ARHGAP17',
#  'ARHGEF7',
#  'ARL1',
#  'ARL14EP',
#  'ARL2',
#  'ARL2BP',
#  'ARL3',
#  'ARL6',
#  'ARL6IP4',
#  'ARL6IP5',
#  'ARL6IP6',
#  'ARL8A',
#  'ARL8B',
#  'ARPC3',
#  'ASS1',
#  'ATL3',
#  'BAIAP2',
#  'BAIAP2L1',
#  'BCAR1',
#  'BIN1',
#  'BIN3',
#  'BLM',
#  'BLVRB',
#  'BMS1',
#  'BOP1',
#  'BUD23',
#  'BYSL',
#  'C9orf78',
#  'CAD',
#  'CALD1',
#  'CALM1',
#  'CAPZB',
#  'CBX1',
#  'CCDC22',
#  'CCDC86',
#  'CCDC93',
#  'CCT2',
#  'CCT3',
#  'CCT4',
#  'CCT5',
#  'CCT6A',
#  'CCT7',
#  'CCT8',
#  'CDC16',
#  'CDC20',
#  'CDC23',
#  'CDC26',
#  'CDC27',
#  'CDKN2A',
#  'CEP131',
#  'CEP135',
#  'CEP78',
#  'CEP85',
#  'CERS6',
#  'CETN2',
#  'CETN3',
#  'CFL1',
#  'CLIP1',
#  'CLNS1A',
#  'CLTA',
#  'COMMD1',
#  'COMMD2',
#  'COMMD4',
#  'COMMD6',
#  'CPSF6',
#  'CSK',
#  'CSNK2B',
#  'CTNNB1',
#  'CTNNBL1',
#  'CUTC',
#  'DAD1',
#  'DBNDD1',
#  'DDB1',
#  'DDOST',
#  'DDX21',
#  'DDX47',
#  'DDX5',
#  'DDX56',
#  'DEPDC1B',
#  'DHTKD1',
#  'DHX37',
#  'DHX9',
#  'DIAPH1',
#  'DKC1',
#  'DNTTIP1',
#  'DNTTIP2',
#  'DOCK11',
#  'DnaJC21',
#  'EBNA1BP2',
#  'EIF2AK2-N',
#  'EIF3K',
#  'EMG1',
#  'ENO1',
#  'ESD',
#  'EWSR1',
#  'FAM13B',
#  'FARP1',
#  'FAU',
#  'FCHSD2',
#  'FHOD1',
#  'FKBP5',
#  'FNBP1L',
#  'G6PD',
#  'GAPDH',
#  'GAR1',
#  'GBF1',
#  'GJA1',
#  'GLUL',
#  'GNL2',
#  'GNL3',
#  'GSTP1',
#  'GTF3A',
#  'GTPBP4',
#  'H1F0',
#  'HEATR3',
#  'HIST2H2BE',
#  'HNRNPA0',
#  'HNRNPL',
#  'ILF3',
#  'IMP3',
#  'INF2',
#  'INTS9',
#  'KIAA0368',
#  'KRAS',
#  'KRT18',
#  'KRTCAP2',
#  'LAMTOR2',
#  'LDHA',
#  'LDHB',
#  'LGALS1',
#  'LTV1',
#  'MAPK1',
#  'MAPK9',
#  'MED10',
#  'MED11',
#  'MED14',
#  'MED15',
#  'MED17',
#  'MED18',
#  'MED19',
#  'MED20',
#  'MED21',
#  'MED22',
#  'MED24',
#  'MED25',
#  'MED27',
#  'MED28',
#  'MED29',
#  'MED31',
#  'MED4',
#  'MED6',
#  'MED8',
#  'MED9',
#  'MIF',
#  'MIS12',
#  'MKI67-N',
#  'MPHOSPH10',
#  'MRTO4',
#  'MTMR3',
#  'MYH9',
#  'MYL12B',
#  'MYO9B',
#  'NAF1',
#  'NANS',
#  'NCL',
#  'NCOA1',
#  'NEFM',
#  'NHP2',
#  'NIFK',
#  'NMD3',
#  'NOL10',
#  'NOL11',
#  'NOM1',
#  'NOP10',
#  'NOP2',
#  'NOP53',
#  'NSA2',
#  'NUMA1',
#  'NVL',
#  'OST4',
#  'OSTC',
#  'PACSIN3',
#  'PAIP1',
#  'PATZ1',
#  'PDCD11',
#  'PDCD6',
#  'PDCL3',
#  'PES1',
#  'PFN1',
#  'PHGDH',
#  'PIK3R1',
#  'PIKFYVE',
#  'PKM',
#  'PKMYT1',
#  'POLR2A',
#  'POLR2B',
#  'POLR2C',
#  'POLR2D',
#  'POLR2E',
#  'POLR2F',
#  'POLR2G',
#  'POLR2H',
#  'POLR2I',
#  'POLR2J',
#  'POLR2K',
#  'POLR3A',
#  'POLR3B',
#  'POLR3C',
#  'POLR3D',
#  'POLR3E',
#  'POLR3F',
#  'POLR3G',
#  'POLR3GL',
#  'POLR3H',
#  'PPP2CA',
#  'PPP2CB',
#  'PSPC1',
#  'RAC1',
#  'RAC3',
#  'RACGAP1',
#  'RALBP1',
#  'RANBP1',
#  'RANBP2',
#  'RBM28',
#  'RER1',
#  'RHOA',
#  'RHOB',
#  'RHOC',
#  'RHOG',
#  'RHOQ',
#  'RNASEH2A',
#  'RND3',
#  'RPAP2',
#  'RPL11',
#  'RPL5',
#  'RPN1',
#  'RPN2',
#  'RPP30',
#  'RPS16',
#  'RRAS2',
#  'RSL1D1',
#  'S100A10',
#  'SBDS',
#  'SEPT11',
#  'SEPT2',
#  'SEPT5',
#  'SEPT6',
#  'SEPT7',
#  'SEPT8',
#  'SEPT9',
#  'SH3GL1',
#  'SH3GLB1',
#  'SH3GLB2',
#  'SMARCA5',
#  'SMC1A',
#  'SMN1',
#  'SNU13',
#  'SNX1',
#  'SNX11',
#  'SNX12',
#  'SNX15',
#  'SNX17',
#  'SNX2',
#  'SNX27',
#  'SNX3',
#  'SNX4',
#  'SNX5',
#  'SNX6',
#  'SNX7',
#  'SOS1',
#  'SPOUT1',
#  'SRI',
#  'SRP54',
#  'SRP68',
#  'SRP9',
#  'SSB',
#  'SSRP1',
#  'STT3A',
#  'STT3B',
#  'SUPT16H',
#  'SUPT5H',
#  'TCOF1',
#  'TDP1',
#  'TJP1',
#  'TJP2',
#  'TMA16',
#  'TOP1',
#  'TP53',
#  'TRAPPC1',
#  'TRAPPC11',
#  'TRAPPC2',
#  'TSR1',
#  'TSR2',
#  'TUBG1',
#  'UBA52',
#  'USP36',
#  'UTP14A',
#  'UTP4',
#  'UTP6',
#  'UTRN',
#  'VASP',
#  'VCL',
#  'VHL',
#  'VPS4A',
#  'VRK1',
#  'WBP2',
#  'WDR12',
#  'WDR3',
#  'WDR46',
#  'WDR75',
#  'XPO1',
#  'YWHAB',
#  'YWHAE',
#  'YWHAG',
#  'YWHAH',
#  'YWHAQ',
#  'YWHAZ',
#  'YY1',
#  'ZCCHC9'}
