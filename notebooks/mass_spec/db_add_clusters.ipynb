# %%
# from urllib import quote_plus as urlquote

import imp
import pdb
import sys
import time
import numpy as np
import pandas as pd

sys.path.append('/Users/kibeom.kim/Documents/GitHub/opencell/')
from opencell.database import models
from opencell.database import utils
from opencell.database import ms_utils
from opencell.database import ms_operations as ms_ops
from opencell.imaging import processors
from opencell import constants

import sqlalchemy
from sqlalchemy import inspect
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric
from sqlalchemy.orm import sessionmaker
from sqlalchemy.orm import scoped_session

# %%
# url = 'postgresql://postgres:password@localhost:5434/opencelldb_dev'
url = utils.url_from_credentials('../../db-credentials-cap.json')

# %%
# start a sequel session
engine = sqlalchemy.create_engine(url)
engine.connect()

session_factory = sessionmaker(bind=engine)
session = scoped_session(session_factory)

# %%
# making new cluster table

Base = models.Base
Base.metadata.create_all(engine)

# %% [markdown]
# ## Import pre-made Cluster Heatmap Table

# %%
cluster = pd.read_pickle('../../opencell/mass_spec/ignore/old_pickles/0626/mcl/upload_table_mcl_haircut_keep_core_50x_i2.0_newman.pkl')

# %%
cluster.to_csv()
# Out:
#       cluster_id  subcluster_id target_name    prey  col_index  row_index  \
# 0              1            0.0        IPO4   RPS3A          0        105
# 1              1            0.0        IPO4    RPS8          0        107
# 2              1            NaN       SRP54   SRP19          1         10
# 3              1            0.0       SRP54   SRP72          1        174
# 4              1            NaN      RPL10A   RPL15          2        134
# ...          ...            ...         ...     ...        ...        ...
# 9585         244          286.0      UTP14A    PARN          0          1
# 9586         244          286.0      UTP14A   DHX37          0          2
# 9587         244          286.0       DHX37  UTP14A          1          0
# 9588         244          286.0       DHX37    PARN          1          1
# 9589         246          288.0    ARHGEF12   GIPC1          0          0
#
#      pulldown_plate_id design_id well_id   hit_id hit_gene_names  \
# ...

# %%
ms_ops.bulk_insert_cluster_heatmap(session, cluster, cluster_str='primary:mcl_i2.0_haircut:keepcore_subcluster:newman_eigen_corecomplex:newman_eigen')

# %%
imp.reload(ms_ops)
# Out:
# <module 'opencell.database.ms_operations' from '/Users/kibeom.kim/Documents/GitHub/opencell/opencell/database/ms_operations.py'>
